# %%
import os
import numpy as np
import pandas as pd
import re
from PIL import Image
from io import BytesIO
from tqdm.auto import tqdm
import random
import json
from collections import Counter
from google.cloud import storage
import logging
import time

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# GCS Configuration
BUCKET_NAME = "logo-generation-dataset"
DATASET_FOLDER = "modern_logo_dataset"

# Local paths
LOCAL_DATA_DIR = "data"
LOCAL_PROCESSED_DIR = os.path.join(LOCAL_DATA_DIR, "processed_modern")

# Creating necessary directories
os.makedirs(LOCAL_DATA_DIR, exist_ok=True)
os.makedirs(LOCAL_PROCESSED_DIR, exist_ok=True)
os.makedirs(os.path.join(LOCAL_PROCESSED_DIR, "images"), exist_ok=True)
os.makedirs(os.path.join(LOCAL_PROCESSED_DIR, "augmented_images"), exist_ok=True)

# GCS Client setup
storage_client = storage.Client()
bucket = storage_client.bucket(BUCKET_NAME)

# %%
def upload_to_gcs(local_path, gcs_path):
    """Uploading a file to GCS bucket"""
    blob = bucket.blob(gcs_path)
    blob.upload_from_filename(local_path)
    logger.info(f"Uploaded {local_path} to gs://{BUCKET_NAME}/{gcs_path}")

# %%
def convert_to_pil_image(image_data):
    """Safely converting various image formats to PIL Image"""
    try:
        # 1. If it's already a PIL Image, return it
        if isinstance(image_data, Image.Image):
            return image_data
        
        # 2. If it's a dictionary with 'bytes' key, convert bytes to PIL Image
        if isinstance(image_data, dict) and 'bytes' in image_data:
            return Image.open(BytesIO(image_data['bytes']))
        
        # 3. If it's bytes directly, convert to PIL Image
        if isinstance(image_data, bytes):
            return Image.open(BytesIO(image_data))
        
        # 4. If it's a numpy array, convert to PIL Image
        if hasattr(image_data, 'shape') and hasattr(image_data, 'dtype'):
            # Convert numpy array to PIL Image
            return Image.fromarray(np.array(image_data))
        
        # If we can't handle the format, log and return None
        logger.error(f"Unknown image format: {type(image_data)}")
        if isinstance(image_data, dict):
            logger.error(f"Dictionary keys: {image_data.keys()}")
        return None
    
    except Exception as e:
        logger.error(f"Error converting image: {e}")
        return None

# %%
def process_image(img, target_size=1024):
    """Processing image: remove background, resize, and center"""
    try:
        # Converting to PIL Image if needed
        img = convert_to_pil_image(img)
        if img is None:
            return None
            
        # Ensuring image is in RGBA mode
        if img.mode != 'RGBA':
            img = img.convert("RGBA")
        
        # Removing background
        from rembg import remove
        img_no_bg = remove(img)
        
        # Creating a new transparent image with target size
        new_img = Image.new("RGBA", (target_size, target_size), (0, 0, 0, 0))
        
        # Resize original image preserving aspect ratio
        width, height = img_no_bg.size
        ratio = min(target_size / width, target_size / height) * 0.85  # 85% of space for margin
        new_width = int(width * ratio)
        new_height = int(height * ratio)
        
        # Using LANCZOS resampling for higher quality downscaling
        img_resized = img_no_bg.resize((new_width, new_height), Image.LANCZOS)
        
        # Center the image
        x_offset = (target_size - new_width) // 2
        y_offset = (target_size - new_height) // 2
        new_img.paste(img_resized, (x_offset, y_offset), img_resized)
        
        return new_img
    except Exception as e:
        logger.error(f"Error processing image: {e}")
        return None

# %%
def generate_company_name(business_type):
    """Generate a plausible company name based on business type"""
    # Dictionary of common prefixes and suffixes for different business types
    business_names = {
        "technology": {
            "prefixes": ["Tech", "Byte", "Data", "Cyber", "Digital", "Smart", "Cloud", "Quantum", "Nexus", "Nova"],
            "suffixes": ["Solutions", "Systems", "Tech", "Technologies", "Innovations", "Labs", "Network", "Dynamics", "Logic", "Wave"],
            "formats": ["{}{}"]  # Format strings for combining parts
        },
        "coffee shop": {
            "prefixes": ["Bean", "Brew", "Coffee", "Café", "Morning", "Daily", "Urban", "Roast", "Aroma", "Java"],
            "suffixes": ["Coffee", "Café", "Roasters", "Brews", "Cup", "House", "Co.", "Corner", "Fix", "Express"],
            "formats": ["{} {}", "{}'s"]
        },
        "restaurant": {
            "prefixes": ["Taste", "Flavor", "The", "Royal", "Urban", "Golden", "Silver", "Blue", "Green", "Red"],
            "suffixes": ["Table", "Kitchen", "Bistro", "Grill", "Eatery", "Cuisine", "Dining", "Restaurant", "House", "Garden"],
            "formats": ["The {} {}", "{} {}", "{}'s"]
        },
        "fitness": {
            "prefixes": ["Flex", "Power", "Strong", "Elite", "Prime", "Peak", "Core", "Iron", "Vital", "Active"],
            "suffixes": ["Fitness", "Gym", "Athletics", "Strength", "Health", "Training", "Performance", "Fit", "Wellness", "Body"],
            "formats": ["{} {}", "{}-{}"]
        },
        "salon": {
            "prefixes": ["Style", "Beauty", "Chic", "Elegant", "Divine", "Classic", "Modern", "Elite", "Pure", "Luxe"],
            "suffixes": ["Salon", "Beauty", "Styles", "Hair", "Cuts", "Studio", "Spa", "Stylists", "Lounge", "Parlor"],
            "formats": ["{} {}", "{}'s", "{} & {}"]
        },
        "design agency": {
            "prefixes": ["Creative", "Design", "Pixel", "Visual", "Idea", "Art", "Studio", "Brand", "Concept", "Identity"],
            "suffixes": ["Design", "Studio", "Creatives", "Agency", "Partners", "Works", "Lab", "Group", "Collective", "Designers"],
            "formats": ["{} {}", "{} + {}", "{} & {}"]
        }
    }
    
    # Default components if business type isn't in our dictionary
    default_components = {
        "prefixes": ["Alpha", "Omega", "Prime", "Core", "Global", "First", "United", "National", "Metro", "City"],
        "suffixes": ["Group", "Inc", "Co", "Company", "Corporation", "Services", "Solutions", "Enterprises", "International", "Associates"],
        "formats": ["{} {}", "{}, {}"]
    }
    
    # Normalizing business type
    normalized_type = business_type.lower() if business_type else "business"
    
    # Find closest match in our dictionary keys
    components = None
    for key in business_names:
        if key in normalized_type:
            components = business_names[key]
            break
    
    # Using default if no match
    if not components:
        components = default_components
    
    # Generating name
    prefix = random.choice(components["prefixes"])
    suffix = random.choice(components["suffixes"])
    name_format = random.choice(components["formats"])
    
    # Format name and return
    name = name_format.format(prefix, suffix)
    return name

def extract_company_name(text):
    """Extracting company name from text description"""
    # Patterns to match company names in quotes
    patterns = [
        r'"([^"]+)"',  # Text in double quotes
        r"'([^']+)'",  # Text in single quotes
        r'called ([A-Z][A-Za-z0-9\s\-&]+)',  # Words after "called" starting with capital letter
        r'named ([A-Z][A-Za-z0-9\s\-&]+)',   # Words after "named" starting with capital letter
        r'for ([A-Z][A-Za-z0-9\s\-&]{2,}?)[ \.,]'  # Words after "for" starting with capital letter
    ]
    
    # Trying each pattern
    for pattern in patterns:
        match = re.search(pattern, text)
        if match:
            name = match.group(1).strip()
            # Cleaning up the name
            name = re.sub(r'[\.,]$', '', name)  # Removing trailing punctuation
            name = re.sub(r'\s+', ' ', name)    # Normalizing whitespace
            if len(name) > 1 and not name.lower() in ['a', 'an', 'the', 'this', 'that', 'logo']:
                return name
    
    return None

# %%
def parse_description(text):
    """Extract key elements from text descriptions"""
    elements = {
        "business_type": "",
        "style": "",
        "composition": "",
        "color_scheme": "",
        "iconography": "",
        "layout": "",
        "company_name": ""
    }
    
    # Clean text
    if not text:
        return elements
    
    # Extracting company name first
    elements["company_name"] = extract_company_name(text)
    
    # Converting to lowercase for pattern matching
    text_lower = text.lower()
    
    # Business type extraction - refined for Modern Logo dataset patterns
    business_match = re.search(r'logo of(?: a| an)? ([a-zA-Z0-9 ]+)', text_lower)
    if business_match:
        elements["business_type"] = business_match.group(1).strip()
    else:
        # Try alternative pattern: "[business type] logo"
        alt_match = re.search(r'([a-zA-Z0-9 ]+) logo', text_lower)
        if alt_match:
            elements["business_type"] = alt_match.group(1).strip()
    
    # Style detection
    style_keywords = {
        "minimalist": ["minimalist", "minimal", "simplistic", "clean lines"],
        "modern": ["modern", "contemporary", "sleek", "current"],
        "vintage": ["vintage", "retro", "classic", "old-fashioned", "nostalgic"],
        "abstract": ["abstract", "artistic", "conceptual", "non-figurative"],
        "geometric": ["geometric", "shapes", "symmetrical", "structured"],
        "elegant": ["elegant", "sophisticated", "refined", "graceful"],
        "bold": ["bold", "strong", "powerful", "striking"],
        "clean": ["clean", "simple", "neat", "uncluttered"],
        "playful": ["playful", "fun", "friendly", "lively", "cheerful"]
    }
    
    for style, keywords in style_keywords.items():
        if any(keyword in text_lower for keyword in keywords):
            elements["style"] = style
            break
    
    # Composition type
    if any(word in text_lower for word in ["wordmark", "text", "letter", "font", "typography", "type"]):
        elements["composition"] = "text-based"
    elif any(word in text_lower for word in ["emblem", "icon", "symbol", "pictorial", "mascot"]):
        elements["composition"] = "graphic-based"
    else:
        elements["composition"] = "combination"
    
    # Color scheme
    color_keywords = {
        "monochrome": ["monochrome", "black and white", "grayscale", "single color"],
        "gradient": ["gradient", "gradation", "fading", "transition"],
        "colorful": ["colorful", "vibrant", "multicolor", "multi-colored"],
        "primary": ["primary colors", "blue and red", "yellow and blue"]
    }
    
    for scheme, keywords in color_keywords.items():
        if any(keyword in text_lower for keyword in keywords):
            elements["color_scheme"] = scheme
            break
    
    # Extract specific colors mentioned
    colors = re.findall(r'(red|blue|green|yellow|purple|orange|black|white|gray|brown|pink|gold|silver|teal|navy|olive|maroon|turquoise)', text_lower)
    if colors:
        elements["color_scheme"] = ", ".join(sorted(set(colors)))
    
    # Layout detection
    layout_keywords = {
        "circular": ["circular", "round", "circle", "spherical", "radial"],
        "horizontal": ["horizontal", "side by side", "landscape", "wide"],
        "vertical": ["vertical", "stacked", "portrait", "tall"],
        "square": ["square", "box", "quadratic", "equilateral"],
        "diagonal": ["diagonal", "slanted", "angled", "tilted"],
        "asymmetric": ["asymmetric", "dynamic", "irregular", "uneven"]
    }
    
    for layout, keywords in layout_keywords.items():
        if any(keyword in text_lower for keyword in keywords):
            elements["layout"] = layout
            break
    
    return elements

# %%
def get_capitalization_variation(name):
    """Generatong capitalization variations for company names"""
    if not name:
        return name
    
    r = random.random()
    if r < 0.15:  # ALL CAPS
        return name.upper()
    elif r < 0.25:  # all lowercase
        return name.lower()
    elif r < 0.4:  # CamelCase (no spaces)
        return ''.join(word.capitalize() for word in name.split())
    elif r < 0.5:  # Alternating case
        return ''.join([c.upper() if i % 2 == 0 else c.lower() for i, c in enumerate(name)])
    elif r < 0.6:  # First Letter Only
        words = name.split()
        if len(words) > 1:
            return words[0].capitalize() + ' ' + ' '.join(w.lower() for w in words[1:])
    
    # Default: Title Case
    return ' '.join(word.capitalize() for word in name.split())

# %%
def load_modern_logo_dataset():
    """Loading the Modern Logo Dataset directly using pandas"""
    logger.info("Loading Modern Logo Dataset...")
    
    try:
        # Using huggingface_hub to download the dataset file
        from huggingface_hub import hf_hub_download, list_repo_files
        
        # Listing files in the repository
        logger.info("Listing files in the HuggingFace repository...")
        files = list_repo_files("logo-wizard/modern-logo-dataset", repo_type="dataset")
        
        # Looking for data files
        data_files = [f for f in files if f.endswith('.parquet') or f.endswith('.csv')]
        logger.info(f"Found data files: {data_files}")
        
        if not data_files:
            raise ValueError("No data files found in repository")
        
        # Downloading the first data file
        file_path = hf_hub_download(
            repo_id="logo-wizard/modern-logo-dataset", 
            filename=data_files[0],
            repo_type="dataset"
        )
        logger.info(f"Downloaded {data_files[0]} to {file_path}")
        
        # Loading based on file type
        if data_files[0].endswith('.parquet'):
            df = pd.read_parquet(file_path)
        elif data_files[0].endswith('.csv'):
            df = pd.read_csv(file_path)
        
        # Log the structure
        logger.info(f"DataFrame shape: {df.shape}")
        logger.info(f"DataFrame columns: {df.columns.tolist()}")
        
        # Print the first sample to understand structure
        if not df.empty:
            sample = df.iloc[0]
            logger.info("First sample:")
            for col in df.columns:
                logger.info(f"  {col}: {type(sample[col])}")
                if col == 'image' and isinstance(sample[col], dict):
                    logger.info(f"  image keys: {sample[col].keys()}")
        
        logger.info(f"Loaded {len(df)} samples")
        return df
    
    except Exception as e:
        logger.error(f"Error loading dataset: {e}")
        raise

# %%
def main():
    """Main function to execute the simplified data preparation pipeline"""
    # Start timing
    start_time = time.time()
    logger.info("Starting Simplified Modern Logo Dataset Preparation")
    
    # Setting output directories
    output_dir = LOCAL_PROCESSED_DIR
    images_dir = os.path.join(output_dir, "images")
    augmented_dir = os.path.join(output_dir, "augmented_images")
    
    # Step 1: Loading the dataset
    try:
        df = load_modern_logo_dataset()
        logger.info(f"Successfully loaded dataset with {len(df)} samples")
        
        # Sample entry for diagnostics
        logger.info("\nDiagnostic information for first sample:")
        sample = df.iloc[0]
        logger.info(f"Text: {sample.get('text', 'No text')}")
        if 'image' in sample:
            if isinstance(sample['image'], dict):
                logger.info(f"Image type: dict with keys {sample['image'].keys()}")
            else:
                logger.info(f"Image type: {type(sample['image'])}")
    except Exception as e:
        logger.error(f"Failed to load dataset: {e}")
        return
    
    # Step 2: Processing images and create metadata
    logger.info("\nProcessing images and creating metadata...")
    metadata = []
    
    for i, row in tqdm(df.iterrows(), total=len(df), desc="Processing logos"):
        try:
            # Extract image and text
            img = row.get('image')
            text = row.get('text', '')
            
            # Processing image
            processed_img = process_image(img)
            if processed_img:
                # Save processed image
                output_filename = f"modern_{i}.png"
                output_path = os.path.join(images_dir, output_filename)
                processed_img.save(output_path)
                
                # Parse description
                elements = parse_description(text)
                
                # Generating company name if none found
                if not elements["company_name"]:
                    elements["company_name"] = generate_company_name(elements["business_type"])
                
                # Add metadata
                elements["original_text"] = text
                elements["dataset"] = "modern_logo"
                elements["filename"] = output_filename
                elements["image_id"] = i
                metadata.append(elements)
                
                # Log progress at intervals
                if (i + 1) % 100 == 0:
                    logger.info(f"Processed {i + 1} images so far")
        except Exception as e:
            logger.error(f"Error processing sample {i}: {e}")
            continue
    
    # Converting metadata to DataFrame
    metadata_df = pd.DataFrame(metadata)
    logger.info(f"Created metadata for {len(metadata_df)} images")
    
    # Step 3: Enhance metadata
    logger.info("\nEnhancing metadata...")
    
    # Standardizing business types
    business_mapping = {
        'coffee': 'coffee shop',
        'cafe': 'coffee shop',
        'tech': 'technology',
        'it': 'technology',
        'electronic': 'technology',
        'hair': 'salon',
        'barbershop': 'salon',
        'beauty': 'salon',
        'food': 'restaurant',
        'design': 'design agency',
        'fitness': 'fitness',
        'gym': 'fitness',
        'hotel': 'hospitality',
        'resort': 'hospitality'
    }
    
    # Applying mapping to standardize business types
    for old, new in business_mapping.items():
        if 'business_type' in metadata_df.columns:
            metadata_df.loc[metadata_df['business_type'].str.contains(old, case=False, na=False), 'business_type'] = new
    
    # Filling missing values with reasonable defaults
    if 'style' in metadata_df.columns:
        metadata_df['style'] = metadata_df['style'].fillna('modern')
    if 'composition' in metadata_df.columns:
        metadata_df['composition'] = metadata_df['composition'].fillna('combination')
    if 'color_scheme' in metadata_df.columns:
        metadata_df['color_scheme'] = metadata_df['color_scheme'].fillna('professional')
    
    # Creating standardized prompt format
    if all(col in metadata_df.columns for col in ['business_type', 'company_name', 'style', 'composition', 'color_scheme']):
        metadata_df['prompt'] = metadata_df.apply(
            lambda row: f"A logo for {row['business_type'] or 'a business'} named \"{row['company_name']}\", " +
                      f"{row['style']} style, " +
                      f"{row['composition']} design with " +
                      f"{row['color_scheme']}" +
                      (f", featuring {row['iconography']} elements" if pd.notna(row.get('iconography')) and row.get('iconography') else "") +
                      (f", in a {row['layout']} layout" if pd.notna(row.get('layout')) and row.get('layout') else "") +
                      ", with clear English text and professional appearance",
            axis=1
        )
    
    # Step 4: Creating augmentations
    logger.info("\nCreating augmentations...")
    
    # Import necessary modules for image augmentation
    from PIL import ImageEnhance
    
    augmentations_per_logo = 3
    augmented_metadata = []
    
    for idx, row in tqdm(metadata_df.iterrows(), total=len(metadata_df), desc="Generating augmentations"):
        try:
            # Loading original image
            img_path = os.path.join(images_dir, row['filename'])
            img = Image.open(img_path).convert("RGBA")
            
            # Generating augmentations
            for i in range(augmentations_per_logo):
                # Making a copy of the image
                aug_img = img.copy()
                
                # Applying augmentations based on index
                if i % 3 == 0:
                    # Brightness and contrast adjustments
                    enhancer = ImageEnhance.Brightness(aug_img)
                    aug_img = enhancer.enhance(random.uniform(0.92, 1.08))
                    enhancer = ImageEnhance.Contrast(aug_img)
                    aug_img = enhancer.enhance(random.uniform(0.95, 1.05))
                elif i % 3 == 1:
                    # Slight rotation
                    angle = random.uniform(-3, 3)
                    aug_img = aug_img.rotate(angle, resample=Image.BICUBIC, expand=False)
                else:
                    # Color adjustments
                    enhancer = ImageEnhance.Color(aug_img)
                    aug_img = enhancer.enhance(random.uniform(0.95, 1.05))
                
                # Saving augmented image
                base_name, ext = os.path.splitext(row['filename'])
                aug_filename = f"{base_name}_aug{i+1}{ext}"
                aug_path = os.path.join(augmented_dir, aug_filename)
                aug_img.save(aug_path, format='PNG')
                
                # Creating metadata for augmentation
                aug_entry = row.copy()
                aug_entry['filename'] = aug_filename
                aug_entry['augmented'] = True
                aug_entry['original_filename'] = row['filename']
                
                # Vary company name capitalization
                if 'company_name' in aug_entry and aug_entry['company_name']:
                    aug_entry['company_name'] = get_capitalization_variation(aug_entry['company_name'])
                
                # Updating prompt with new company name
                if 'prompt' in aug_entry and 'company_name' in aug_entry:
                    style_variations = [
                        ", with fine details",
                        ", with precise elements",
                        ", with professional finish",
                        ", with balanced composition",
                        ", with premium appearance"
                    ]
                    
                    # Updating prompt with new company name and style variation
                    business_type = aug_entry.get('business_type', 'business')
                    style = aug_entry.get('style', 'modern')
                    composition = aug_entry.get('composition', 'combination')
                    color_scheme = aug_entry.get('color_scheme', 'professional colors')
                    
                    aug_entry['prompt'] = (
                        f"A logo for {business_type} named \"{aug_entry['company_name']}\", "
                        f"{style} style, "
                        f"{composition} design with {color_scheme}"
                        + random.choice(style_variations)
                    )
                
                augmented_metadata.append(aug_entry)
        except Exception as e:
            logger.error(f"Error augmenting {row['filename']}: {e}")
            continue
    
    # Creating DataFrame with augmentations
    aug_df = pd.DataFrame(augmented_metadata)
    logger.info(f"Created {len(aug_df)} augmentations")
    
    # Combine original and augmented metadata
    combined_df = pd.concat([metadata_df, aug_df], ignore_index=True)
    logger.info(f"Total dataset size: {len(combined_df)} logos")
    
    # Step 5: Saving all results
    logger.info("\nSaving results...")
    
    # Saving metadata CSV files
    metadata_df.to_csv(os.path.join(output_dir, "modern_metadata.csv"), index=False)
    aug_df.to_csv(os.path.join(output_dir, "modern_augmented_metadata.csv"), index=False)
    combined_df.to_csv(os.path.join(output_dir, "modern_combined_with_augmentations.csv"), index=False)
    
    # Creating training data JSON
    training_data = []
    for _, row in combined_df.iterrows():
        img_dir = "augmented_images" if row.get('augmented', False) else "images"
        file_name = row['filename']
        
        training_data.append({
            "file_name": file_name,
            "prompt": row['prompt'] if 'prompt' in row else f"A logo for {row.get('business_type', 'a business')}",
            "augmented": bool(row.get('augmented', False))
        })
    
    # Saving training data JSON
    with open(os.path.join(output_dir, "modern_training_data.json"), 'w') as f:
        json.dump(training_data, f, indent=2)
    
    # Step 6: Uploading results to GCS
    logger.info("\nUploading results to GCS...")
    
    # Uploading all processed images
    logger.info("Uploading processed images...")
    for file in tqdm(os.listdir(images_dir), desc="Uploading images"):
        if file.endswith(('.png', '.jpg')):
            local_path = os.path.join(images_dir, file)
            gcs_path = f"{DATASET_FOLDER}/images/{file}"
            upload_to_gcs(local_path, gcs_path)
    
    # Uploading all augmented images
    logger.info("Uploading augmented images...")
    for file in tqdm(os.listdir(augmented_dir), desc="Uploading augmented images"):
        if file.endswith(('.png', '.jpg')):
            local_path = os.path.join(augmented_dir, file)
            gcs_path = f"{DATASET_FOLDER}/augmented_images/{file}"
            upload_to_gcs(local_path, gcs_path)
    
    # Uploading metadata files
    upload_to_gcs(
        os.path.join(output_dir, "modern_metadata.csv"), 
        f"{DATASET_FOLDER}/modern_metadata.csv"
    )
    upload_to_gcs(
        os.path.join(output_dir, "modern_augmented_metadata.csv"), 
        f"{DATASET_FOLDER}/modern_augmented_metadata.csv"
    )
    upload_to_gcs(
        os.path.join(output_dir, "modern_combined_with_augmentations.csv"), 
        f"{DATASET_FOLDER}/modern_combined_with_augmentations.csv"
    )
    upload_to_gcs(
        os.path.join(output_dir, "modern_training_data.json"), 
        f"{DATASET_FOLDER}/modern_training_data.json"
    )
    
    # Calculating execution time
    execution_time = time.time() - start_time
    hours, remainder = divmod(execution_time, 3600)
    minutes, seconds = divmod(remainder, 60)
    
    logger.info(f"\nData preparation completed successfully!")
    logger.info(f"Total execution time: {int(hours)}h {int(minutes)}m {int(seconds)}s")
    logger.info(f"Processed {len(metadata_df)} original logos and created {len(aug_df)} augmentations")
    logger.info(f"Final dataset contains {len(combined_df)} logos")
    logger.info(f"Data saved locally to {output_dir} and synced to GCS: gs://{BUCKET_NAME}/{DATASET_FOLDER}")

if __name__ == "__main__":
    try:
        main()
    except Exception as e:
        logger.error(f"Error in data preparation: {e}", exc_info=True)
# Out:
# 2025-04-30 16:12:40,343 - INFO - Starting Simplified Modern Logo Dataset Preparation
# 2025-04-30 16:12:40,344 - INFO - Loading Modern Logo Dataset...
# 2025-04-30 16:12:40,949 - INFO - Listing files in the HuggingFace repository...
# 2025-04-30 16:12:41,071 - INFO - Found data files: ['data/train-00000-of-00001-b64601da56687a05.parquet']
# 2025-04-30 16:12:41,146 - INFO - Downloaded data/train-00000-of-00001-b64601da56687a05.parquet to /home/jupyter/.cache/huggingface/hub/datasets--logo-wizard--modern-logo-dataset/snapshots/82051101cfdf253729e5f418c38d2d1305ef0a91/data/train-00000-of-00001-b64601da56687a05.parquet
# 2025-04-30 16:12:44,075 - INFO - DataFrame shape: (803, 2)
# 2025-04-30 16:12:44,076 - INFO - DataFrame columns: ['image', 'text']
# 2025-04-30 16:12:44,077 - INFO - First sample:
# 2025-04-30 16:12:44,077 - INFO -   image: <class 'dict'>
# 2025-04-30 16:12:44,078 - INFO -   image keys: dict_keys(['bytes', 'path'])
# 2025-04-30 16:12:44,079 - INFO -   text: <class 'str'>
# 2025-04-30 16:12:44,079 - INFO - Loaded 803 samples
# 2025-04-30 16:12:44,079 - INFO - Successfully loaded dataset with 803 samples
# 2025-04-30 16:12:44,080 - INFO -
# Diagnostic information for first sample:
# 2025-04-30 16:12:44,080 - INFO - Text: "a logo of coffee shop, take-away coffee cardboard glass with white and brown stripes and dark brown lid, coffee circle with three cream drops, white background, brown foreground, minimalism, modern"
# 2025-04-30 16:12:44,081 - INFO - Image type: dict with keys dict_keys(['bytes', 'path'])
# 2025-04-30 16:12:44,081 - INFO -
# Processing images and creating metadata...
# Processing logos:   0%|          | 0/803 [00:00<?, ?it/s]
# 2025-04-30 16:14:39,365 - INFO - Processed 100 images so far
# 2025-04-30 16:16:27,404 - INFO - Processed 200 images so far
# 2025-04-30 16:18:14,556 - INFO - Processed 300 images so far
# 2025-04-30 16:20:04,959 - INFO - Processed 400 images so far
# 2025-04-30 16:21:52,389 - INFO - Processed 500 images so far
# 2025-04-30 16:23:40,405 - INFO - Processed 600 images so far
# 2025-04-30 16:25:29,262 - INFO - Processed 700 images so far
# 2025-04-30 16:27:17,337 - INFO - Processed 800 images so far
# 2025-04-30 16:27:20,527 - INFO - Created metadata for 803 images
# 2025-04-30 16:27:20,528 - INFO -
# Enhancing metadata...
# 2025-04-30 16:27:20,567 - INFO -
# Creating augmentations...
# Generating augmentations:   0%|          | 0/803 [00:00<?, ?it/s]
# 2025-04-30 16:33:40,073 - INFO - Created 2409 augmentations
# 2025-04-30 16:33:40,076 - INFO - Total dataset size: 3212 logos
# 2025-04-30 16:33:40,077 - INFO -
# Saving results...
# 2025-04-30 16:33:40,450 - INFO -
# Uploading results to GCS...
# 2025-04-30 16:33:40,451 - INFO - Uploading processed images...
# Uploading images:   0%|          | 0/803 [00:00<?, ?it/s]
# 2025-04-30 16:33:40,527 - INFO - Uploaded data/processed_modern/images/modern_272.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_272.png
# 2025-04-30 16:33:40,584 - INFO - Uploaded data/processed_modern/images/modern_25.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_25.png
# 2025-04-30 16:33:40,647 - INFO - Uploaded data/processed_modern/images/modern_589.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_589.png
# 2025-04-30 16:33:40,706 - INFO - Uploaded data/processed_modern/images/modern_183.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_183.png
# 2025-04-30 16:33:40,770 - INFO - Uploaded data/processed_modern/images/modern_466.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_466.png
# 2025-04-30 16:33:40,829 - INFO - Uploaded data/processed_modern/images/modern_598.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_598.png
# 2025-04-30 16:33:40,883 - INFO - Uploaded data/processed_modern/images/modern_550.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_550.png
# 2025-04-30 16:33:40,942 - INFO - Uploaded data/processed_modern/images/modern_228.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_228.png
# 2025-04-30 16:33:40,989 - INFO - Uploaded data/processed_modern/images/modern_610.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_610.png
# 2025-04-30 16:33:41,055 - INFO - Uploaded data/processed_modern/images/modern_227.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_227.png
# 2025-04-30 16:33:41,124 - INFO - Uploaded data/processed_modern/images/modern_169.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_169.png
# 2025-04-30 16:33:41,183 - INFO - Uploaded data/processed_modern/images/modern_708.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_708.png
# 2025-04-30 16:33:41,241 - INFO - Uploaded data/processed_modern/images/modern_606.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_606.png
# 2025-04-30 16:33:41,296 - INFO - Uploaded data/processed_modern/images/modern_755.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_755.png
# 2025-04-30 16:33:41,353 - INFO - Uploaded data/processed_modern/images/modern_167.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_167.png
# 2025-04-30 16:33:41,427 - INFO - Uploaded data/processed_modern/images/modern_497.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_497.png
# 2025-04-30 16:33:41,477 - INFO - Uploaded data/processed_modern/images/modern_235.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_235.png
# 2025-04-30 16:33:41,525 - INFO - Uploaded data/processed_modern/images/modern_37.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_37.png
# 2025-04-30 16:33:41,586 - INFO - Uploaded data/processed_modern/images/modern_299.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_299.png
# 2025-04-30 16:33:41,647 - INFO - Uploaded data/processed_modern/images/modern_770.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_770.png
# 2025-04-30 16:33:41,698 - INFO - Uploaded data/processed_modern/images/modern_223.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_223.png
# 2025-04-30 16:33:41,755 - INFO - Uploaded data/processed_modern/images/modern_106.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_106.png
# 2025-04-30 16:33:41,802 - INFO - Uploaded data/processed_modern/images/modern_733.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_733.png
# 2025-04-30 16:33:41,859 - INFO - Uploaded data/processed_modern/images/modern_9.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_9.png
# 2025-04-30 16:33:41,915 - INFO - Uploaded data/processed_modern/images/modern_0.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_0.png
# 2025-04-30 16:33:41,993 - INFO - Uploaded data/processed_modern/images/modern_171.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_171.png
# 2025-04-30 16:33:42,052 - INFO - Uploaded data/processed_modern/images/modern_534.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_534.png
# 2025-04-30 16:33:42,113 - INFO - Uploaded data/processed_modern/images/modern_28.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_28.png
# 2025-04-30 16:33:42,174 - INFO - Uploaded data/processed_modern/images/modern_682.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_682.png
# 2025-04-30 16:33:42,225 - INFO - Uploaded data/processed_modern/images/modern_60.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_60.png
# 2025-04-30 16:33:42,277 - INFO - Uploaded data/processed_modern/images/modern_400.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_400.png
# 2025-04-30 16:33:42,330 - INFO - Uploaded data/processed_modern/images/modern_509.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_509.png
# 2025-04-30 16:33:42,388 - INFO - Uploaded data/processed_modern/images/modern_596.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_596.png
# 2025-04-30 16:33:42,445 - INFO - Uploaded data/processed_modern/images/modern_292.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_292.png
# 2025-04-30 16:33:42,501 - INFO - Uploaded data/processed_modern/images/modern_173.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_173.png
# 2025-04-30 16:33:42,552 - INFO - Uploaded data/processed_modern/images/modern_273.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_273.png
# 2025-04-30 16:33:42,603 - INFO - Uploaded data/processed_modern/images/modern_428.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_428.png
# 2025-04-30 16:33:42,656 - INFO - Uploaded data/processed_modern/images/modern_547.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_547.png
# 2025-04-30 16:33:42,707 - INFO - Uploaded data/processed_modern/images/modern_182.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_182.png
# 2025-04-30 16:33:42,787 - INFO - Uploaded data/processed_modern/images/modern_492.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_492.png
# 2025-04-30 16:33:42,847 - INFO - Uploaded data/processed_modern/images/modern_116.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_116.png
# 2025-04-30 16:33:42,905 - INFO - Uploaded data/processed_modern/images/modern_471.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_471.png
# 2025-04-30 16:33:42,965 - INFO - Uploaded data/processed_modern/images/modern_483.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_483.png
# 2025-04-30 16:33:43,020 - INFO - Uploaded data/processed_modern/images/modern_750.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_750.png
# 2025-04-30 16:33:43,082 - INFO - Uploaded data/processed_modern/images/modern_126.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_126.png
# 2025-04-30 16:33:43,136 - INFO - Uploaded data/processed_modern/images/modern_42.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_42.png
# 2025-04-30 16:33:43,197 - INFO - Uploaded data/processed_modern/images/modern_633.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_633.png
# 2025-04-30 16:33:43,253 - INFO - Uploaded data/processed_modern/images/modern_795.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_795.png
# 2025-04-30 16:33:43,305 - INFO - Uploaded data/processed_modern/images/modern_78.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_78.png
# 2025-04-30 16:33:43,352 - INFO - Uploaded data/processed_modern/images/modern_12.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_12.png
# 2025-04-30 16:33:43,406 - INFO - Uploaded data/processed_modern/images/modern_415.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_415.png
# 2025-04-30 16:33:43,456 - INFO - Uploaded data/processed_modern/images/modern_756.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_756.png
# 2025-04-30 16:33:43,505 - INFO - Uploaded data/processed_modern/images/modern_565.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_565.png
# 2025-04-30 16:33:43,562 - INFO - Uploaded data/processed_modern/images/modern_670.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_670.png
# 2025-04-30 16:33:43,619 - INFO - Uploaded data/processed_modern/images/modern_87.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_87.png
# 2025-04-30 16:33:43,671 - INFO - Uploaded data/processed_modern/images/modern_414.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_414.png
# 2025-04-30 16:33:43,721 - INFO - Uploaded data/processed_modern/images/modern_487.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_487.png
# 2025-04-30 16:33:43,783 - INFO - Uploaded data/processed_modern/images/modern_669.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_669.png
# 2025-04-30 16:33:43,838 - INFO - Uploaded data/processed_modern/images/modern_366.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_366.png
# 2025-04-30 16:33:43,885 - INFO - Uploaded data/processed_modern/images/modern_562.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_562.png
# 2025-04-30 16:33:43,937 - INFO - Uploaded data/processed_modern/images/modern_188.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_188.png
# 2025-04-30 16:33:43,999 - INFO - Uploaded data/processed_modern/images/modern_135.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_135.png
# 2025-04-30 16:33:44,060 - INFO - Uploaded data/processed_modern/images/modern_398.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_398.png
# 2025-04-30 16:33:44,109 - INFO - Uploaded data/processed_modern/images/modern_149.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_149.png
# 2025-04-30 16:33:44,159 - INFO - Uploaded data/processed_modern/images/modern_592.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_592.png
# 2025-04-30 16:33:44,210 - INFO - Uploaded data/processed_modern/images/modern_749.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_749.png
# 2025-04-30 16:33:44,258 - INFO - Uploaded data/processed_modern/images/modern_325.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_325.png
# 2025-04-30 16:33:44,314 - INFO - Uploaded data/processed_modern/images/modern_675.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_675.png
# 2025-04-30 16:33:44,367 - INFO - Uploaded data/processed_modern/images/modern_13.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_13.png
# 2025-04-30 16:33:44,436 - INFO - Uploaded data/processed_modern/images/modern_630.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_630.png
# 2025-04-30 16:33:44,499 - INFO - Uploaded data/processed_modern/images/modern_637.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_637.png
# 2025-04-30 16:33:44,559 - INFO - Uploaded data/processed_modern/images/modern_773.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_773.png
# 2025-04-30 16:33:44,612 - INFO - Uploaded data/processed_modern/images/modern_326.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_326.png
# 2025-04-30 16:33:44,662 - INFO - Uploaded data/processed_modern/images/modern_66.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_66.png
# 2025-04-30 16:33:44,727 - INFO - Uploaded data/processed_modern/images/modern_426.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_426.png
# 2025-04-30 16:33:44,785 - INFO - Uploaded data/processed_modern/images/modern_536.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_536.png
# 2025-04-30 16:33:44,850 - INFO - Uploaded data/processed_modern/images/modern_342.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_342.png
# 2025-04-30 16:33:44,917 - INFO - Uploaded data/processed_modern/images/modern_764.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_764.png
# 2025-04-30 16:33:44,965 - INFO - Uploaded data/processed_modern/images/modern_29.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_29.png
# 2025-04-30 16:33:45,020 - INFO - Uploaded data/processed_modern/images/modern_747.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_747.png
# 2025-04-30 16:33:45,079 - INFO - Uploaded data/processed_modern/images/modern_267.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_267.png
# 2025-04-30 16:33:45,144 - INFO - Uploaded data/processed_modern/images/modern_658.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_658.png
# 2025-04-30 16:33:45,194 - INFO - Uploaded data/processed_modern/images/modern_433.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_433.png
# 2025-04-30 16:33:45,241 - INFO - Uploaded data/processed_modern/images/modern_641.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_641.png
# 2025-04-30 16:33:45,296 - INFO - Uploaded data/processed_modern/images/modern_297.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_297.png
# 2025-04-30 16:33:45,346 - INFO - Uploaded data/processed_modern/images/modern_403.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_403.png
# 2025-04-30 16:33:45,408 - INFO - Uploaded data/processed_modern/images/modern_251.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_251.png
# 2025-04-30 16:33:45,473 - INFO - Uploaded data/processed_modern/images/modern_523.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_523.png
# 2025-04-30 16:33:45,523 - INFO - Uploaded data/processed_modern/images/modern_44.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_44.png
# 2025-04-30 16:33:45,580 - INFO - Uploaded data/processed_modern/images/modern_155.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_155.png
# 2025-04-30 16:33:45,633 - INFO - Uploaded data/processed_modern/images/modern_704.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_704.png
# 2025-04-30 16:33:45,689 - INFO - Uploaded data/processed_modern/images/modern_495.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_495.png
# 2025-04-30 16:33:45,747 - INFO - Uploaded data/processed_modern/images/modern_88.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_88.png
# 2025-04-30 16:33:45,805 - INFO - Uploaded data/processed_modern/images/modern_625.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_625.png
# 2025-04-30 16:33:45,870 - INFO - Uploaded data/processed_modern/images/modern_125.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_125.png
# 2025-04-30 16:33:45,976 - INFO - Uploaded data/processed_modern/images/modern_120.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_120.png
# 2025-04-30 16:33:46,031 - INFO - Uploaded data/processed_modern/images/modern_93.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_93.png
# 2025-04-30 16:33:46,083 - INFO - Uploaded data/processed_modern/images/modern_560.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_560.png
# 2025-04-30 16:33:46,143 - INFO - Uploaded data/processed_modern/images/modern_440.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_440.png
# 2025-04-30 16:33:46,197 - INFO - Uploaded data/processed_modern/images/modern_324.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_324.png
# 2025-04-30 16:33:46,255 - INFO - Uploaded data/processed_modern/images/modern_61.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_61.png
# 2025-04-30 16:33:46,311 - INFO - Uploaded data/processed_modern/images/modern_615.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_615.png
# 2025-04-30 16:33:46,368 - INFO - Uploaded data/processed_modern/images/modern_590.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_590.png
# 2025-04-30 16:33:46,415 - INFO - Uploaded data/processed_modern/images/modern_41.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_41.png
# 2025-04-30 16:33:46,461 - INFO - Uploaded data/processed_modern/images/modern_338.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_338.png
# 2025-04-30 16:33:46,514 - INFO - Uploaded data/processed_modern/images/modern_661.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_661.png
# 2025-04-30 16:33:46,569 - INFO - Uploaded data/processed_modern/images/modern_464.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_464.png
# 2025-04-30 16:33:46,623 - INFO - Uploaded data/processed_modern/images/modern_663.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_663.png
# 2025-04-30 16:33:46,682 - INFO - Uploaded data/processed_modern/images/modern_612.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_612.png
# 2025-04-30 16:33:46,728 - INFO - Uploaded data/processed_modern/images/modern_465.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_465.png
# 2025-04-30 16:33:46,783 - INFO - Uploaded data/processed_modern/images/modern_46.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_46.png
# 2025-04-30 16:33:46,832 - INFO - Uploaded data/processed_modern/images/modern_232.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_232.png
# 2025-04-30 16:33:46,885 - INFO - Uploaded data/processed_modern/images/modern_359.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_359.png
# 2025-04-30 16:33:46,940 - INFO - Uploaded data/processed_modern/images/modern_79.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_79.png
# 2025-04-30 16:33:46,997 - INFO - Uploaded data/processed_modern/images/modern_449.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_449.png
# 2025-04-30 16:33:47,049 - INFO - Uploaded data/processed_modern/images/modern_460.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_460.png
# 2025-04-30 16:33:47,115 - INFO - Uploaded data/processed_modern/images/modern_237.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_237.png
# 2025-04-30 16:33:47,168 - INFO - Uploaded data/processed_modern/images/modern_151.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_151.png
# 2025-04-30 16:33:47,227 - INFO - Uploaded data/processed_modern/images/modern_384.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_384.png
# 2025-04-30 16:33:47,302 - INFO - Uploaded data/processed_modern/images/modern_123.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_123.png
# 2025-04-30 16:33:47,362 - INFO - Uploaded data/processed_modern/images/modern_474.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_474.png
# 2025-04-30 16:33:47,414 - INFO - Uploaded data/processed_modern/images/modern_715.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_715.png
# 2025-04-30 16:33:47,466 - INFO - Uploaded data/processed_modern/images/modern_115.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_115.png
# 2025-04-30 16:33:47,516 - INFO - Uploaded data/processed_modern/images/modern_206.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_206.png
# 2025-04-30 16:33:47,569 - INFO - Uploaded data/processed_modern/images/modern_70.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_70.png
# 2025-04-30 16:33:47,618 - INFO - Uploaded data/processed_modern/images/modern_371.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_371.png
# 2025-04-30 16:33:47,668 - INFO - Uploaded data/processed_modern/images/modern_407.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_407.png
# 2025-04-30 16:33:47,717 - INFO - Uploaded data/processed_modern/images/modern_394.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_394.png
# 2025-04-30 16:33:47,771 - INFO - Uploaded data/processed_modern/images/modern_336.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_336.png
# 2025-04-30 16:33:47,842 - INFO - Uploaded data/processed_modern/images/modern_422.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_422.png
# 2025-04-30 16:33:47,911 - INFO - Uploaded data/processed_modern/images/modern_774.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_774.png
# 2025-04-30 16:33:47,973 - INFO - Uploaded data/processed_modern/images/modern_420.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_420.png
# 2025-04-30 16:33:48,024 - INFO - Uploaded data/processed_modern/images/modern_341.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_341.png
# 2025-04-30 16:33:48,068 - INFO - Uploaded data/processed_modern/images/modern_280.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_280.png
# 2025-04-30 16:33:48,116 - INFO - Uploaded data/processed_modern/images/modern_337.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_337.png
# 2025-04-30 16:33:48,177 - INFO - Uploaded data/processed_modern/images/modern_253.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_253.png
# 2025-04-30 16:33:48,245 - INFO - Uploaded data/processed_modern/images/modern_360.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_360.png
# 2025-04-30 16:33:48,297 - INFO - Uploaded data/processed_modern/images/modern_219.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_219.png
# 2025-04-30 16:33:48,348 - INFO - Uploaded data/processed_modern/images/modern_3.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_3.png
# 2025-04-30 16:33:48,403 - INFO - Uploaded data/processed_modern/images/modern_129.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_129.png
# 2025-04-30 16:33:48,497 - INFO - Uploaded data/processed_modern/images/modern_80.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_80.png
# 2025-04-30 16:33:48,564 - INFO - Uploaded data/processed_modern/images/modern_738.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_738.png
# 2025-04-30 16:33:48,614 - INFO - Uploaded data/processed_modern/images/modern_648.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_648.png
# 2025-04-30 16:33:48,684 - INFO - Uploaded data/processed_modern/images/modern_482.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_482.png
# 2025-04-30 16:33:48,737 - INFO - Uploaded data/processed_modern/images/modern_725.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_725.png
# 2025-04-30 16:33:48,789 - INFO - Uploaded data/processed_modern/images/modern_439.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_439.png
# 2025-04-30 16:33:48,840 - INFO - Uploaded data/processed_modern/images/modern_277.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_277.png
# 2025-04-30 16:33:48,892 - INFO - Uploaded data/processed_modern/images/modern_767.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_767.png
# 2025-04-30 16:33:48,966 - INFO - Uploaded data/processed_modern/images/modern_729.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_729.png
# 2025-04-30 16:33:49,030 - INFO - Uploaded data/processed_modern/images/modern_548.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_548.png
# 2025-04-30 16:33:49,079 - INFO - Uploaded data/processed_modern/images/modern_86.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_86.png
# 2025-04-30 16:33:49,125 - INFO - Uploaded data/processed_modern/images/modern_787.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_787.png
# 2025-04-30 16:33:49,183 - INFO - Uploaded data/processed_modern/images/modern_163.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_163.png
# 2025-04-30 16:33:49,235 - INFO - Uploaded data/processed_modern/images/modern_216.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_216.png
# 2025-04-30 16:33:49,281 - INFO - Uploaded data/processed_modern/images/modern_570.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_570.png
# 2025-04-30 16:33:49,336 - INFO - Uploaded data/processed_modern/images/modern_616.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_616.png
# 2025-04-30 16:33:49,392 - INFO - Uploaded data/processed_modern/images/modern_401.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_401.png
# 2025-04-30 16:33:49,439 - INFO - Uploaded data/processed_modern/images/modern_699.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_699.png
# 2025-04-30 16:33:49,489 - INFO - Uploaded data/processed_modern/images/modern_744.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_744.png
# 2025-04-30 16:33:49,595 - INFO - Uploaded data/processed_modern/images/modern_207.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_207.png
# 2025-04-30 16:33:49,652 - INFO - Uploaded data/processed_modern/images/modern_85.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_85.png
# 2025-04-30 16:33:49,724 - INFO - Uploaded data/processed_modern/images/modern_775.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_775.png
# 2025-04-30 16:33:49,775 - INFO - Uploaded data/processed_modern/images/modern_581.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_581.png
# 2025-04-30 16:33:49,832 - INFO - Uploaded data/processed_modern/images/modern_734.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_734.png
# 2025-04-30 16:33:49,886 - INFO - Uploaded data/processed_modern/images/modern_412.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_412.png
# 2025-04-30 16:33:49,936 - INFO - Uploaded data/processed_modern/images/modern_90.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_90.png
# 2025-04-30 16:33:49,980 - INFO - Uploaded data/processed_modern/images/modern_458.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_458.png
# 2025-04-30 16:33:50,039 - INFO - Uploaded data/processed_modern/images/modern_631.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_631.png
# 2025-04-30 16:33:50,093 - INFO - Uploaded data/processed_modern/images/modern_526.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_526.png
# 2025-04-30 16:33:50,144 - INFO - Uploaded data/processed_modern/images/modern_329.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_329.png
# 2025-04-30 16:33:50,216 - INFO - Uploaded data/processed_modern/images/modern_441.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_441.png
# 2025-04-30 16:33:50,268 - INFO - Uploaded data/processed_modern/images/modern_187.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_187.png
# 2025-04-30 16:33:50,320 - INFO - Uploaded data/processed_modern/images/modern_379.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_379.png
# 2025-04-30 16:33:50,399 - INFO - Uploaded data/processed_modern/images/modern_192.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_192.png
# 2025-04-30 16:33:50,454 - INFO - Uploaded data/processed_modern/images/modern_639.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_639.png
# 2025-04-30 16:33:50,503 - INFO - Uploaded data/processed_modern/images/modern_50.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_50.png
# 2025-04-30 16:33:50,554 - INFO - Uploaded data/processed_modern/images/modern_549.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_549.png
# 2025-04-30 16:33:50,615 - INFO - Uploaded data/processed_modern/images/modern_528.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_528.png
# 2025-04-30 16:33:50,667 - INFO - Uploaded data/processed_modern/images/modern_362.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_362.png
# 2025-04-30 16:33:50,732 - INFO - Uploaded data/processed_modern/images/modern_789.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_789.png
# 2025-04-30 16:33:50,782 - INFO - Uploaded data/processed_modern/images/modern_719.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_719.png
# 2025-04-30 16:33:50,828 - INFO - Uploaded data/processed_modern/images/modern_580.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_580.png
# 2025-04-30 16:33:50,881 - INFO - Uploaded data/processed_modern/images/modern_82.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_82.png
# 2025-04-30 16:33:50,934 - INFO - Uploaded data/processed_modern/images/modern_649.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_649.png
# 2025-04-30 16:33:50,981 - INFO - Uploaded data/processed_modern/images/modern_643.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_643.png
# 2025-04-30 16:33:51,028 - INFO - Uploaded data/processed_modern/images/modern_98.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_98.png
# 2025-04-30 16:33:51,082 - INFO - Uploaded data/processed_modern/images/modern_364.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_364.png
# 2025-04-30 16:33:51,134 - INFO - Uploaded data/processed_modern/images/modern_445.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_445.png
# 2025-04-30 16:33:51,206 - INFO - Uploaded data/processed_modern/images/modern_157.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_157.png
# 2025-04-30 16:33:51,258 - INFO - Uploaded data/processed_modern/images/modern_150.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_150.png
# 2025-04-30 16:33:51,319 - INFO - Uploaded data/processed_modern/images/modern_443.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_443.png
# 2025-04-30 16:33:51,374 - INFO - Uploaded data/processed_modern/images/modern_11.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_11.png
# 2025-04-30 16:33:51,428 - INFO - Uploaded data/processed_modern/images/modern_249.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_249.png
# 2025-04-30 16:33:51,475 - INFO - Uploaded data/processed_modern/images/modern_40.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_40.png
# 2025-04-30 16:33:51,523 - INFO - Uploaded data/processed_modern/images/modern_728.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_728.png
# 2025-04-30 16:33:51,570 - INFO - Uploaded data/processed_modern/images/modern_399.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_399.png
# 2025-04-30 16:33:51,660 - INFO - Uploaded data/processed_modern/images/modern_105.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_105.png
# 2025-04-30 16:33:51,710 - INFO - Uploaded data/processed_modern/images/modern_32.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_32.png
# 2025-04-30 16:33:51,757 - INFO - Uploaded data/processed_modern/images/modern_275.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_275.png
# 2025-04-30 16:33:51,806 - INFO - Uploaded data/processed_modern/images/modern_525.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_525.png
# 2025-04-30 16:33:51,863 - INFO - Uploaded data/processed_modern/images/modern_591.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_591.png
# 2025-04-30 16:33:51,919 - INFO - Uploaded data/processed_modern/images/modern_211.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_211.png
# 2025-04-30 16:33:51,972 - INFO - Uploaded data/processed_modern/images/modern_145.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_145.png
# 2025-04-30 16:33:52,031 - INFO - Uploaded data/processed_modern/images/modern_385.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_385.png
# 2025-04-30 16:33:52,086 - INFO - Uploaded data/processed_modern/images/modern_668.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_668.png
# 2025-04-30 16:33:52,144 - INFO - Uploaded data/processed_modern/images/modern_97.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_97.png
# 2025-04-30 16:33:52,188 - INFO - Uploaded data/processed_modern/images/modern_638.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_638.png
# 2025-04-30 16:33:52,241 - INFO - Uploaded data/processed_modern/images/modern_698.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_698.png
# 2025-04-30 16:33:52,324 - INFO - Uploaded data/processed_modern/images/modern_367.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_367.png
# 2025-04-30 16:33:52,386 - INFO - Uploaded data/processed_modern/images/modern_791.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_791.png
# 2025-04-30 16:33:52,438 - INFO - Uploaded data/processed_modern/images/modern_607.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_607.png
# 2025-04-30 16:33:52,494 - INFO - Uploaded data/processed_modern/images/modern_479.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_479.png
# 2025-04-30 16:33:52,539 - INFO - Uploaded data/processed_modern/images/modern_566.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_566.png
# 2025-04-30 16:33:52,594 - INFO - Uploaded data/processed_modern/images/modern_242.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_242.png
# 2025-04-30 16:33:52,646 - INFO - Uploaded data/processed_modern/images/modern_45.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_45.png
# 2025-04-30 16:33:52,712 - INFO - Uploaded data/processed_modern/images/modern_674.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_674.png
# 2025-04-30 16:33:52,767 - INFO - Uploaded data/processed_modern/images/modern_303.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_303.png
# 2025-04-30 16:33:52,820 - INFO - Uploaded data/processed_modern/images/modern_777.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_777.png
# 2025-04-30 16:33:52,871 - INFO - Uploaded data/processed_modern/images/modern_640.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_640.png
# 2025-04-30 16:33:52,919 - INFO - Uploaded data/processed_modern/images/modern_69.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_69.png
# 2025-04-30 16:33:52,972 - INFO - Uploaded data/processed_modern/images/modern_137.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_137.png
# 2025-04-30 16:33:53,031 - INFO - Uploaded data/processed_modern/images/modern_321.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_321.png
# 2025-04-30 16:33:53,085 - INFO - Uploaded data/processed_modern/images/modern_2.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_2.png
# 2025-04-30 16:33:53,134 - INFO - Uploaded data/processed_modern/images/modern_202.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_202.png
# 2025-04-30 16:33:53,190 - INFO - Uploaded data/processed_modern/images/modern_26.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_26.png
# 2025-04-30 16:33:53,243 - INFO - Uploaded data/processed_modern/images/modern_696.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_696.png
# 2025-04-30 16:33:53,286 - INFO - Uploaded data/processed_modern/images/modern_529.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_529.png
# 2025-04-30 16:33:53,341 - INFO - Uploaded data/processed_modern/images/modern_437.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_437.png
# 2025-04-30 16:33:53,398 - INFO - Uploaded data/processed_modern/images/modern_452.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_452.png
# 2025-04-30 16:33:53,446 - INFO - Uploaded data/processed_modern/images/modern_741.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_741.png
# 2025-04-30 16:33:53,497 - INFO - Uploaded data/processed_modern/images/modern_47.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_47.png
# 2025-04-30 16:33:53,574 - INFO - Uploaded data/processed_modern/images/modern_305.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_305.png
# 2025-04-30 16:33:53,616 - INFO - Uploaded data/processed_modern/images/modern_539.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_539.png
# 2025-04-30 16:33:53,671 - INFO - Uploaded data/processed_modern/images/modern_198.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_198.png
# 2025-04-30 16:33:53,727 - INFO - Uploaded data/processed_modern/images/modern_284.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_284.png
# 2025-04-30 16:33:53,785 - INFO - Uploaded data/processed_modern/images/modern_376.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_376.png
# 2025-04-30 16:33:53,832 - INFO - Uploaded data/processed_modern/images/modern_543.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_543.png
# 2025-04-30 16:33:53,896 - INFO - Uploaded data/processed_modern/images/modern_410.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_410.png
# 2025-04-30 16:33:53,945 - INFO - Uploaded data/processed_modern/images/modern_582.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_582.png
# 2025-04-30 16:33:54,002 - INFO - Uploaded data/processed_modern/images/modern_330.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_330.png
# 2025-04-30 16:33:54,059 - INFO - Uploaded data/processed_modern/images/modern_722.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_722.png
# 2025-04-30 16:33:54,110 - INFO - Uploaded data/processed_modern/images/modern_238.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_238.png
# 2025-04-30 16:33:54,156 - INFO - Uploaded data/processed_modern/images/modern_140.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_140.png
# 2025-04-30 16:33:54,212 - INFO - Uploaded data/processed_modern/images/modern_113.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_113.png
# 2025-04-30 16:33:54,274 - INFO - Uploaded data/processed_modern/images/modern_349.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_349.png
# 2025-04-30 16:33:54,324 - INFO - Uploaded data/processed_modern/images/modern_416.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_416.png
# 2025-04-30 16:33:54,379 - INFO - Uploaded data/processed_modern/images/modern_59.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_59.png
# 2025-04-30 16:33:54,462 - INFO - Uploaded data/processed_modern/images/modern_594.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_594.png
# 2025-04-30 16:33:54,525 - INFO - Uploaded data/processed_modern/images/modern_101.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_101.png
# 2025-04-30 16:33:54,576 - INFO - Uploaded data/processed_modern/images/modern_361.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_361.png
# 2025-04-30 16:33:54,632 - INFO - Uploaded data/processed_modern/images/modern_378.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_378.png
# 2025-04-30 16:33:54,683 - INFO - Uploaded data/processed_modern/images/modern_109.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_109.png
# 2025-04-30 16:33:54,738 - INFO - Uploaded data/processed_modern/images/modern_122.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_122.png
# 2025-04-30 16:33:54,798 - INFO - Uploaded data/processed_modern/images/modern_14.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_14.png
# 2025-04-30 16:33:54,850 - INFO - Uploaded data/processed_modern/images/modern_39.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_39.png
# 2025-04-30 16:33:54,910 - INFO - Uploaded data/processed_modern/images/modern_754.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_754.png
# 2025-04-30 16:33:54,961 - INFO - Uploaded data/processed_modern/images/modern_417.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_417.png
# 2025-04-30 16:33:55,020 - INFO - Uploaded data/processed_modern/images/modern_419.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_419.png
# 2025-04-30 16:33:55,077 - INFO - Uploaded data/processed_modern/images/modern_516.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_516.png
# 2025-04-30 16:33:55,144 - INFO - Uploaded data/processed_modern/images/modern_185.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_185.png
# 2025-04-30 16:33:55,194 - INFO - Uploaded data/processed_modern/images/modern_799.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_799.png
# 2025-04-30 16:33:55,270 - INFO - Uploaded data/processed_modern/images/modern_731.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_731.png
# 2025-04-30 16:33:55,324 - INFO - Uploaded data/processed_modern/images/modern_679.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_679.png
# 2025-04-30 16:33:55,383 - INFO - Uploaded data/processed_modern/images/modern_413.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_413.png
# 2025-04-30 16:33:55,434 - INFO - Uploaded data/processed_modern/images/modern_302.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_302.png
# 2025-04-30 16:33:55,489 - INFO - Uploaded data/processed_modern/images/modern_792.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_792.png
# 2025-04-30 16:33:55,543 - INFO - Uploaded data/processed_modern/images/modern_688.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_688.png
# 2025-04-30 16:33:55,624 - INFO - Uploaded data/processed_modern/images/modern_647.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_647.png
# 2025-04-30 16:33:55,689 - INFO - Uploaded data/processed_modern/images/modern_58.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_58.png
# 2025-04-30 16:33:55,747 - INFO - Uploaded data/processed_modern/images/modern_636.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_636.png
# 2025-04-30 16:33:55,801 - INFO - Uploaded data/processed_modern/images/modern_761.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_761.png
# 2025-04-30 16:33:55,886 - INFO - Uploaded data/processed_modern/images/modern_475.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_475.png
# 2025-04-30 16:33:55,939 - INFO - Uploaded data/processed_modern/images/modern_200.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_200.png
# 2025-04-30 16:33:55,990 - INFO - Uploaded data/processed_modern/images/modern_498.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_498.png
# 2025-04-30 16:33:56,042 - INFO - Uploaded data/processed_modern/images/modern_389.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_389.png
# 2025-04-30 16:33:56,096 - INFO - Uploaded data/processed_modern/images/modern_481.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_481.png
# 2025-04-30 16:33:56,158 - INFO - Uploaded data/processed_modern/images/modern_569.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_569.png
# 2025-04-30 16:33:56,206 - INFO - Uploaded data/processed_modern/images/modern_262.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_262.png
# 2025-04-30 16:33:56,275 - INFO - Uploaded data/processed_modern/images/modern_264.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_264.png
# 2025-04-30 16:33:56,330 - INFO - Uploaded data/processed_modern/images/modern_136.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_136.png
# 2025-04-30 16:33:56,373 - INFO - Uploaded data/processed_modern/images/modern_700.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_700.png
# 2025-04-30 16:33:56,419 - INFO - Uploaded data/processed_modern/images/modern_656.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_656.png
# 2025-04-30 16:33:56,469 - INFO - Uploaded data/processed_modern/images/modern_726.png to gs://logo-generation-dataset/modern_logo_dataset/images/modern_726.png
# ...
# 2025-04-30 16:36:30,752 - INFO - Uploaded data/processed_modern/augmented_images/modern_657_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_657_aug3.png
# 2025-04-30 16:36:30,837 - INFO - Uploaded data/processed_modern/augmented_images/modern_637_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_637_aug1.png
# 2025-04-30 16:36:30,892 - INFO - Uploaded data/processed_modern/augmented_images/modern_759_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_759_aug2.png
# 2025-04-30 16:36:30,941 - INFO - Uploaded data/processed_modern/augmented_images/modern_138_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_138_aug3.png
# 2025-04-30 16:36:30,992 - INFO - Uploaded data/processed_modern/augmented_images/modern_573_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_573_aug3.png
# 2025-04-30 16:36:31,101 - INFO - Uploaded data/processed_modern/augmented_images/modern_8_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_8_aug2.png
# 2025-04-30 16:36:31,153 - INFO - Uploaded data/processed_modern/augmented_images/modern_104_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_104_aug1.png
# 2025-04-30 16:36:31,201 - INFO - Uploaded data/processed_modern/augmented_images/modern_602_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_602_aug2.png
# 2025-04-30 16:36:31,288 - INFO - Uploaded data/processed_modern/augmented_images/modern_266_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_266_aug2.png
# 2025-04-30 16:36:31,347 - INFO - Uploaded data/processed_modern/augmented_images/modern_468_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_468_aug2.png
# 2025-04-30 16:36:31,404 - INFO - Uploaded data/processed_modern/augmented_images/modern_702_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_702_aug2.png
# 2025-04-30 16:36:31,454 - INFO - Uploaded data/processed_modern/augmented_images/modern_301_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_301_aug1.png
# 2025-04-30 16:36:31,511 - INFO - Uploaded data/processed_modern/augmented_images/modern_10_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_10_aug3.png
# 2025-04-30 16:36:31,566 - INFO - Uploaded data/processed_modern/augmented_images/modern_511_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_511_aug1.png
# 2025-04-30 16:36:31,618 - INFO - Uploaded data/processed_modern/augmented_images/modern_775_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_775_aug3.png
# 2025-04-30 16:36:31,676 - INFO - Uploaded data/processed_modern/augmented_images/modern_460_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_460_aug2.png
# 2025-04-30 16:36:31,731 - INFO - Uploaded data/processed_modern/augmented_images/modern_200_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_200_aug1.png
# 2025-04-30 16:36:31,782 - INFO - Uploaded data/processed_modern/augmented_images/modern_310_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_310_aug2.png
# 2025-04-30 16:36:31,833 - INFO - Uploaded data/processed_modern/augmented_images/modern_302_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_302_aug1.png
# 2025-04-30 16:36:31,883 - INFO - Uploaded data/processed_modern/augmented_images/modern_488_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_488_aug2.png
# 2025-04-30 16:36:31,929 - INFO - Uploaded data/processed_modern/augmented_images/modern_333_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_333_aug1.png
# 2025-04-30 16:36:31,974 - INFO - Uploaded data/processed_modern/augmented_images/modern_664_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_664_aug2.png
# 2025-04-30 16:36:32,032 - INFO - Uploaded data/processed_modern/augmented_images/modern_762_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_762_aug2.png
# 2025-04-30 16:36:32,107 - INFO - Uploaded data/processed_modern/augmented_images/modern_75_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_75_aug1.png
# 2025-04-30 16:36:32,167 - INFO - Uploaded data/processed_modern/augmented_images/modern_474_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_474_aug3.png
# 2025-04-30 16:36:32,247 - INFO - Uploaded data/processed_modern/augmented_images/modern_379_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_379_aug1.png
# 2025-04-30 16:36:32,301 - INFO - Uploaded data/processed_modern/augmented_images/modern_640_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_640_aug3.png
# 2025-04-30 16:36:32,379 - INFO - Uploaded data/processed_modern/augmented_images/modern_752_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_752_aug3.png
# 2025-04-30 16:36:32,433 - INFO - Uploaded data/processed_modern/augmented_images/modern_495_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_495_aug3.png
# 2025-04-30 16:36:32,489 - INFO - Uploaded data/processed_modern/augmented_images/modern_649_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_649_aug3.png
# 2025-04-30 16:36:32,542 - INFO - Uploaded data/processed_modern/augmented_images/modern_291_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_291_aug1.png
# 2025-04-30 16:36:32,591 - INFO - Uploaded data/processed_modern/augmented_images/modern_585_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_585_aug2.png
# 2025-04-30 16:36:32,644 - INFO - Uploaded data/processed_modern/augmented_images/modern_487_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_487_aug2.png
# 2025-04-30 16:36:32,700 - INFO - Uploaded data/processed_modern/augmented_images/modern_612_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_612_aug3.png
# 2025-04-30 16:36:32,770 - INFO - Uploaded data/processed_modern/augmented_images/modern_717_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_717_aug3.png
# 2025-04-30 16:36:32,814 - INFO - Uploaded data/processed_modern/augmented_images/modern_685_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_685_aug1.png
# 2025-04-30 16:36:32,855 - INFO - Uploaded data/processed_modern/augmented_images/modern_711_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_711_aug2.png
# 2025-04-30 16:36:32,927 - INFO - Uploaded data/processed_modern/augmented_images/modern_321_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_321_aug3.png
# 2025-04-30 16:36:32,987 - INFO - Uploaded data/processed_modern/augmented_images/modern_295_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_295_aug2.png
# 2025-04-30 16:36:33,072 - INFO - Uploaded data/processed_modern/augmented_images/modern_453_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_453_aug1.png
# 2025-04-30 16:36:33,118 - INFO - Uploaded data/processed_modern/augmented_images/modern_748_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_748_aug1.png
# 2025-04-30 16:36:33,166 - INFO - Uploaded data/processed_modern/augmented_images/modern_273_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_273_aug1.png
# 2025-04-30 16:36:33,222 - INFO - Uploaded data/processed_modern/augmented_images/modern_90_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_90_aug2.png
# 2025-04-30 16:36:33,275 - INFO - Uploaded data/processed_modern/augmented_images/modern_253_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_253_aug1.png
# 2025-04-30 16:36:33,321 - INFO - Uploaded data/processed_modern/augmented_images/modern_352_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_352_aug2.png
# 2025-04-30 16:36:33,374 - INFO - Uploaded data/processed_modern/augmented_images/modern_556_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_556_aug3.png
# 2025-04-30 16:36:33,433 - INFO - Uploaded data/processed_modern/augmented_images/modern_288_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_288_aug1.png
# 2025-04-30 16:36:33,479 - INFO - Uploaded data/processed_modern/augmented_images/modern_439_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_439_aug1.png
# 2025-04-30 16:36:33,524 - INFO - Uploaded data/processed_modern/augmented_images/modern_600_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_600_aug2.png
# 2025-04-30 16:36:33,571 - INFO - Uploaded data/processed_modern/augmented_images/modern_99_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_99_aug3.png
# 2025-04-30 16:36:33,625 - INFO - Uploaded data/processed_modern/augmented_images/modern_393_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_393_aug1.png
# 2025-04-30 16:36:33,686 - INFO - Uploaded data/processed_modern/augmented_images/modern_738_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_738_aug3.png
# 2025-04-30 16:36:33,737 - INFO - Uploaded data/processed_modern/augmented_images/modern_793_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_793_aug1.png
# 2025-04-30 16:36:33,788 - INFO - Uploaded data/processed_modern/augmented_images/modern_327_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_327_aug2.png
# 2025-04-30 16:36:33,842 - INFO - Uploaded data/processed_modern/augmented_images/modern_118_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_118_aug3.png
# 2025-04-30 16:36:33,886 - INFO - Uploaded data/processed_modern/augmented_images/modern_194_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_194_aug3.png
# 2025-04-30 16:36:33,937 - INFO - Uploaded data/processed_modern/augmented_images/modern_297_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_297_aug3.png
# 2025-04-30 16:36:33,996 - INFO - Uploaded data/processed_modern/augmented_images/modern_374_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_374_aug1.png
# 2025-04-30 16:36:34,045 - INFO - Uploaded data/processed_modern/augmented_images/modern_268_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_268_aug1.png
# 2025-04-30 16:36:34,093 - INFO - Uploaded data/processed_modern/augmented_images/modern_764_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_764_aug2.png
# 2025-04-30 16:36:34,152 - INFO - Uploaded data/processed_modern/augmented_images/modern_290_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_290_aug3.png
# 2025-04-30 16:36:34,217 - INFO - Uploaded data/processed_modern/augmented_images/modern_183_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_183_aug2.png
# 2025-04-30 16:36:34,260 - INFO - Uploaded data/processed_modern/augmented_images/modern_540_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_540_aug3.png
# 2025-04-30 16:36:34,310 - INFO - Uploaded data/processed_modern/augmented_images/modern_635_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_635_aug3.png
# 2025-04-30 16:36:34,357 - INFO - Uploaded data/processed_modern/augmented_images/modern_609_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_609_aug3.png
# 2025-04-30 16:36:34,396 - INFO - Uploaded data/processed_modern/augmented_images/modern_122_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_122_aug3.png
# 2025-04-30 16:36:34,448 - INFO - Uploaded data/processed_modern/augmented_images/modern_4_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_4_aug1.png
# 2025-04-30 16:36:34,497 - INFO - Uploaded data/processed_modern/augmented_images/modern_15_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_15_aug2.png
# 2025-04-30 16:36:34,553 - INFO - Uploaded data/processed_modern/augmented_images/modern_213_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_213_aug3.png
# 2025-04-30 16:36:34,605 - INFO - Uploaded data/processed_modern/augmented_images/modern_784_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_784_aug3.png
# 2025-04-30 16:36:34,651 - INFO - Uploaded data/processed_modern/augmented_images/modern_373_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_373_aug1.png
# 2025-04-30 16:36:34,719 - INFO - Uploaded data/processed_modern/augmented_images/modern_123_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_123_aug3.png
# 2025-04-30 16:36:34,790 - INFO - Uploaded data/processed_modern/augmented_images/modern_651_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_651_aug1.png
# 2025-04-30 16:36:34,842 - INFO - Uploaded data/processed_modern/augmented_images/modern_632_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_632_aug3.png
# 2025-04-30 16:36:34,922 - INFO - Uploaded data/processed_modern/augmented_images/modern_770_aug1.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_770_aug1.png
# 2025-04-30 16:36:34,983 - INFO - Uploaded data/processed_modern/augmented_images/modern_796_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_796_aug2.png
# 2025-04-30 16:36:35,037 - INFO - Uploaded data/processed_modern/augmented_images/modern_126_aug3.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_126_aug3.png
# 2025-04-30 16:36:35,101 - INFO - Uploaded data/processed_modern/augmented_images/modern_153_aug2.png to gs://logo-generation-dataset/modern_logo_dataset/augmented_images/modern_153_aug2.png
# 2025-04-30 16:36:35,162 - INFO - Uploaded data/processed_modern/modern_metadata.csv to gs://logo-generation-dataset/modern_logo_dataset/modern_metadata.csv
# 2025-04-30 16:36:35,252 - INFO - Uploaded data/processed_modern/modern_augmented_metadata.csv to gs://logo-generation-dataset/modern_logo_dataset/modern_augmented_metadata.csv
# 2025-04-30 16:36:35,346 - INFO - Uploaded data/processed_modern/modern_combined_with_augmentations.csv to gs://logo-generation-dataset/modern_logo_dataset/modern_combined_with_augmentations.csv
# 2025-04-30 16:36:35,408 - INFO - Uploaded data/processed_modern/modern_training_data.json to gs://logo-generation-dataset/modern_logo_dataset/modern_training_data.json
# 2025-04-30 16:36:35,408 - INFO -
# Data preparation completed successfully!
# 2025-04-30 16:36:35,409 - INFO - Total execution time: 0h 23m 55s
# 2025-04-30 16:36:35,409 - INFO - Processed 803 original logos and created 2409 augmentations
# 2025-04-30 16:36:35,410 - INFO - Final dataset contains 3212 logos
# 2025-04-30 16:36:35,411 - INFO - Data saved locally to data/processed_modern and synced to GCS: gs://logo-generation-dataset/modern_logo_dataset
